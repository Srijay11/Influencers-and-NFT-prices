# %% [markdown]
# <a href="https://colab.research.google.com/github/Srijay11/Influencers-and-NFT-prices/blob/main/TweetScraperV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/tweepy/tweepy.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/tweepy/tweepy.git to /tmp/pip-req-build-c2hf2nad
#   Running command git clone --filter=blob:none --quiet https://github.com/tweepy/tweepy.git /tmp/pip-req-build-c2hf2nad
#   Resolved https://github.com/tweepy/tweepy.git to commit 5d22a01a2f48feaed6817e0ab7c27a990735a3d8
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 1.7 MB/s eta 0:00:00
# ...
#   Created wheel for tweepy: filename=tweepy-4.12.1-py3-none-any.whl size=102528 sha256=60edfad96959f24d9b8cb4f94d26433ad7d0f0e59ffcd3c35590351e589a9060
#   Stored in directory: /tmp/pip-ephem-wheel-cache-95651clj/wheels/ad/05/51/a78f66d15b87f9c623d2f3afc4401660ac4219e526c787fb8b
# Successfully built tweepy
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
# ...

# %%
import pandas as pd
import tweepy
from datetime import datetime, timedelta
consumer_key = "J5Cvx3QDtzXFlLlJeT7zDz8PW" #Your API/Consumer key 
consumer_secret = "QmGsPI5GeecBucBlq9WRUla3ttUuOIkZkqRyXQe7kbTG8dA21p" #Your API/Consumer Secret Key
access_token = "1311770104057659392-FlV5bK5bPmoiCVu6etMWiZi6svBcpJ"    #Your Access token key
access_token_secret = "JeawjPQ1IeXEyMQNmd369Twh3deMtFhFER6d5IQnJiKwF" #Your Access token Secret key

#Pass in our twitter API authentication key
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret,
    access_token, access_token_secret
)

# %%
import tweepy
import pandas as pd
consumer_key = "J5Cvx3QDtzXFlLlJeT7zDz8PW" #Your API/Consumer key 
consumer_secret = "QmGsPI5GeecBucBlq9WRUla3ttUuOIkZkqRyXQe7kbTG8dA21p" #Your API/Consumer Secret Key
access_token = "1311770104057659392-FlV5bK5bPmoiCVu6etMWiZi6svBcpJ"    #Your Access token key
access_token_secret = "JeawjPQ1IeXEyMQNmd369Twh3deMtFhFER6d5IQnJiKwF" #Your Access token Secret key

#Pass in our twitter API authentication key
auth = tweepy.OAuth1UserHandler(
    consumer_key, consumer_secret,
    access_token, access_token_secret
)

#Instantiate the tweepy API
api = tweepy.API(auth, wait_on_rate_limit=True)


search_query = "Nfts"
no_of_tweets =5000


try:
    #The number of tweets we want to retrieved from the search
    tweets = api.search_tweets(q=search_query, count=no_of_tweets)
    
    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
    
    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))

# %%
search_query = "Non Fungible Tokens"
no_of_tweets =5000


try:
    #The number of tweets we want to retrieved from the search
    tweets = api.search_tweets(q=search_query, count=no_of_tweets)
    
    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
    
    #Creation of Dataframe
    tweets_df_v2 = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))

# %%
tweets_df.shape
# Out:
# (72, 5)

# %%
display(tweets_df)
# Out:
#                           User              Date Created  Number of Likes  \
# 0              vanadij75.bnb 🛸 2023-02-13 06:32:13+00:00                0
# 1                   QUL artist 2023-02-13 06:32:12+00:00                0
# 2                        wiwin 2023-02-13 06:32:11+00:00                0
# 3                 丗sou-gallery 2023-02-13 06:32:11+00:00                0
# 4                  Viceroy_Ash 2023-02-13 06:32:10+00:00                0
# ..                         ...                       ...              ...
# 67  Teh ary𖧷̷۪۪ᰰ Free tag𖧷̷۪۪ᰰ 2023-02-13 06:31:36+00:00                0
# 68                    h1t3kc0r 2023-02-13 06:31:36+00:00                0
# 69                NFTEye_Alpha 2023-02-13 06:31:36+00:00                0
# 70                   september 2023-02-13 06:31:35+00:00                0
# 71                       Ak47♛ 2023-02-13 06:31:35+00:00                0
#
#           Source of Tweet                                              Tweet
# ...

# %%
tweets_df['Tweet'].loc[tweets_df.index[0]]
# Out:
# 'RT @Fractal_Visions: OMEGA APE 🦍 MINTING NOW\n\nFree Claim 🙏🙏🙏\n\nOnly 111 NFTs available!\n\nHolders only.. 🔥🙏🔥\n\nhttps://t.co/s2F9p0qPNn https:/…'

# %%
display(tweets_df_v2)
# Out:
#                   User              Date Created  Number of Likes  \
# 0      Coinrunners.NFT 2023-02-13 04:33:00+00:00                0
# 1    Buratti Art Group 2023-02-13 02:36:34+00:00                0
# 2       Chopsticks {🔤} 2023-02-12 23:43:52+00:00                1
# 3       Audrey Nelma🇺🇬 2023-02-12 22:16:59+00:00                0
# 4   Ignatius Nikulsons 2023-02-12 22:05:00+00:00                0
# ..                 ...                       ...              ...
# 95                Jeff 2023-02-12 15:42:10+00:00                0
# 96            😍𝓐𝓷𝓽𝓱𝓸𝓷𝔂 2023-02-12 15:28:57+00:00                0
# 97           😚ᴀɴᴛʜᴏɴʏ😙 2023-02-12 15:24:50+00:00                0
# 98            👾Steven🖖 2023-02-12 15:23:50+00:00                0
# 99           🤪𝙍𝙞𝙘𝙝𝙖𝙧𝙙🤟 2023-02-12 15:23:35+00:00                0
#
#        Source of Tweet                                              Tweet
# 0      Twitter Web App  #COINRUNNERS NFTS are fractionalised NFTs\nyou...
# ...

# %%
display(tweets_df)
# Out:
#                           User              Date Created  Number of Likes  \
# 0              vanadij75.bnb 🛸 2023-02-13 06:32:13+00:00                0
# 1                   QUL artist 2023-02-13 06:32:12+00:00                0
# 2                        wiwin 2023-02-13 06:32:11+00:00                0
# 3                 丗sou-gallery 2023-02-13 06:32:11+00:00                0
# 4                  Viceroy_Ash 2023-02-13 06:32:10+00:00                0
# ..                         ...                       ...              ...
# 67  Teh ary𖧷̷۪۪ᰰ Free tag𖧷̷۪۪ᰰ 2023-02-13 06:31:36+00:00                0
# 68                    h1t3kc0r 2023-02-13 06:31:36+00:00                0
# 69                NFTEye_Alpha 2023-02-13 06:31:36+00:00                0
# 70                   september 2023-02-13 06:31:35+00:00                0
# 71                       Ak47♛ 2023-02-13 06:31:35+00:00                0
#
#           Source of Tweet                                              Tweet
# ...

# %%
api = tweepy.API(auth)

# Define the hashtag to search for
hashtag = "#NFTs"

# Extract tweets with the hashtag
tweets = tweepy.Cursor(api.search_tweets,
              q=hashtag,
              lang="en",
              tweet_mode='extended').items(1000)

# Create a list to store the tweets
tweet_list = []

# Iterate over the tweets and store the relevant information in the list
for tweet in tweets:
    tweet_list.append({
        "created_at": tweet.created_at,
        "text": tweet.full_text,
        "user_id": tweet.user.id,
        "user_name": tweet.user.screen_name,
        "user_location": tweet.user.location
    })

# Convert the list of tweets into a Pandas DataFrame
df3 = pd.DataFrame(tweet_list)

# Print the DataFrame
print(df3)
# Out:
#                    created_at  \
# 0   2023-02-13 06:32:14+00:00
# 1   2023-02-13 06:32:12+00:00
# 2   2023-02-13 06:32:11+00:00
# 3   2023-02-13 06:32:10+00:00
# 4   2023-02-13 06:32:09+00:00
# ..                        ...
# 995 2023-02-13 06:18:49+00:00
# 996 2023-02-13 06:18:48+00:00
# 997 2023-02-13 06:18:48+00:00
# 998 2023-02-13 06:18:48+00:00
# 999 2023-02-13 06:18:48+00:00
#
#                                                   text              user_id  \
# 0    RT @Wahgmi: Hakoiri x Wahgmi 🐋 \n\nThe Next A1...  1549296727160590336
# 1    RT @Bildaldil_NFT: SOLD 😭\n\nAaa Thank you @fi...  1568821237887139840
# 2    RT @nft_wearr: StripperCoin Merchandise collec...  1578394884825751553
# 3    RT @KeyboardWIC: kwic://phase.2\n\nThe first l...           3505084402
# 4    RT @xrpwalkers: Happy Saturday Twitter ☀️ \n\n...  1571978524470411264
# ..                                                 ...                  ...
# ...

# %%
api = tweepy.API(auth)

# Define the hashtag to search for
hashtag = "#NFTs"


# Extract tweets with the hashtag
tweets = tweepy.Cursor(api.search_tweets,
                       q=hashtag,lang="en",
                       tweet_mode='extended',
                       ).items(1000)

# Create a list to store the tweets
tweet_list = []

# Iterate over the tweets and store the relevant information in the list
for tweet in tweets:
    tweet_list.append({
        "User": tweet.user.name,
        "Date Created": tweet.created_at,
        "Number of Likes": tweet.favorite_count,
        "Source of Tweet": tweet.source,
        "Tweet": tweet.full_text
    })
    
# Convert the list of tweets into a Pandas DataFrame
df4 = pd.DataFrame(tweet_list)
#df4 = df4[["User","Date Created","Number of Likes","Source of Tweet","Tweet"]]
#df4 = pd.DataFrame(tweet,columns=['User','Date Created','Number of Likes','Source of Tweet','Tweet'])
# Print the DataFrame
print(df4)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-14-49acf1d8758c> in <module>
#      15
#      16 # Iterate over the tweets and store the relevant information in the list
# ---> 17 for tweet in tweets:
#      18     tweet_list.append({
#      19         "User": tweet.user.name,
#
# /usr/local/lib/python3.8/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.8/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
# ...

# %%
#Instantiate the tweepy API
api = tweepy.API(auth, wait_on_rate_limit=True)


search_query = "#Nfts"
no_of_tweets =5000


try:
    #The number of tweets we want to retrieved from the search
    tweets = api.search_tweets(q=search_query, count=no_of_tweets)
    
    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.user.name, tweet.created_at, tweet.favorite_count, tweet.source,  tweet.text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]
    
    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))

# %%
print(tweets_df)

# %%
# Create API object
api = tweepy.API(auth)

# Define the hashtag to search for
hashtag = "#Nfts"

# Define the time interval to search for tweets
end_date = datetime.now()
start_date = end_date - timedelta(days=180)

# Extract tweets with the hashtag and within the specified time interval
tweets = tweepy.Cursor(api.search_tweets,
              q=hashtag,
              lang="en",
              tweet_mode='extended',
              since_id=start_date,
              max_id=end_date).items(100)

# Create a list to store the tweets
tweet_list = []

# Iterate over the tweets and store the relevant information in the list
for tweet in tweets:
    tweet_list.append({
        "created_at": tweet.created_at,
        "text": tweet.full_text,
        "user_id": tweet.user.id,
        "user_name": tweet.user.screen_name,
        "user_location": tweet.user.location
    })
# Print the number of tweets extracted
print("Number of tweets extracted:", len(tweet_list))
# Convert the list of tweets into a Pandas DataFrame
df5 = pd.DataFrame(tweet_list)

# Organize the format of the DataFrame
#df5 = df5[["created_at", "text", "user_id", "user_name", "user_location"]]

# Print the DataFrame
print(df5)

# %%
import requests
import pandas as pd

# Define the API endpoint
endpoint = "https://api.nftmarketplace.com/v1/nfts/<nft_id>"

# Send a request to the API to get the NFT data
response = requests.get(endpoint)

# Extract the NFT data from the response
nft_data = response.json()

# Store the NFT data in a pandas DataFrame
df = pd.DataFrame(nft_data)

# Plot the price data over time
df.plot(x='timestamp', y='price')
